# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('Chronic kidney disease prediction.csv')

# %%
dataset
# Out:
#      age         bp sg  al  su     rbc        pc         pcc          ba  \
# 0      2  76.459948  c   3   0  normal  abnormal  notpresent  notpresent
# 1      3  76.459948  c   2   0  normal    normal  notpresent  notpresent
# 2      4  76.459948  a   1   0  normal    normal  notpresent  notpresent
# 3      5  76.459948  d   1   0  normal    normal  notpresent  notpresent
# 4      5  50.000000  c   0   0  normal    normal  notpresent  notpresent
# ..   ...        ... ..  ..  ..     ...       ...         ...         ...
# 394   97  70.000000  a   0   0  normal    normal  notpresent  notpresent
# 395   97  70.000000  c   0   2  normal    normal  notpresent  notpresent
# 396   98  70.000000  c   3   0  normal    normal  notpresent  notpresent
# 397   99  90.000000  a   0   0  normal    normal  notpresent  notpresent
# 398   99  80.000000  a   0   0  normal    normal  notpresent  notpresent
#
#             bgr  ...        pcv            wc        rc  htn   dm  cad  appet  \
# ...

# %%
dataset.Possible.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
#it replaces 'yes' with 1 and 'no' with 0.
dataset['Possible'] = dataset['Possible'].replace(['yes','no'], [1,0])

# %%
dataset
# Out:
#      age         bp sg  al  su     rbc        pc         pcc          ba  \
# 0      2  76.459948  c   3   0  normal  abnormal  notpresent  notpresent
# 1      3  76.459948  c   2   0  normal    normal  notpresent  notpresent
# 2      4  76.459948  a   1   0  normal    normal  notpresent  notpresent
# 3      5  76.459948  d   1   0  normal    normal  notpresent  notpresent
# 4      5  50.000000  c   0   0  normal    normal  notpresent  notpresent
# ..   ...        ... ..  ..  ..     ...       ...         ...         ...
# 394   97  70.000000  a   0   0  normal    normal  notpresent  notpresent
# 395   97  70.000000  c   0   2  normal    normal  notpresent  notpresent
# 396   98  70.000000  c   3   0  normal    normal  notpresent  notpresent
# 397   99  90.000000  a   0   0  normal    normal  notpresent  notpresent
# 398   99  80.000000  a   0   0  normal    normal  notpresent  notpresent
#
#             bgr  ...        pcv            wc        rc  htn   dm  cad  appet  \
# ...

# %%
#displays the first few rows of the dataset stored in the variable 
dataset.head(6)
# Out:
#    age         bp sg  al  su       rbc        pc         pcc          ba  \
# 0    2  76.459948  c   3   0    normal  abnormal  notpresent  notpresent
# 1    3  76.459948  c   2   0    normal    normal  notpresent  notpresent
# 2    4  76.459948  a   1   0    normal    normal  notpresent  notpresent
# 3    5  76.459948  d   1   0    normal    normal  notpresent  notpresent
# 4    5  50.000000  c   0   0    normal    normal  notpresent  notpresent
# 5    6  60.000000  c   4   0  abnormal  abnormal  notpresent     present
#
#           bgr  ...        pcv            wc        rc  htn  dm  cad  appet  \
# 0  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 1  148.112676  ...  34.000000  12300.000000  4.705597   no  no   no    yes
# 2   99.000000  ...  34.000000   8408.191126  4.705597   no  no   no    yes
# 3  148.112676  ...  38.868902   8408.191126  4.705597   no  no   no    yes
# 4  148.112676  ...  36.000000  12400.000000  4.705597   no  no   no    yes
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 25 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       399 non-null    int64
#  1   bp        399 non-null    float64
#  2   sg        399 non-null    object
#  3   al        399 non-null    int64
#  4   su        399 non-null    int64
#  5   rbc       399 non-null    object
#  6   pc        399 non-null    object
#  7   pcc       399 non-null    object
#  8   ba        399 non-null    object
#  9   bgr       399 non-null    float64
#  10  bu        399 non-null    float64
#  11  sc        399 non-null    float64
#  12  sod       399 non-null    float64
#  13  pot       399 non-null    float64
#  14  hrmo      399 non-null    float64
#  15  pcv       399 non-null    float64
#  16  wc        399 non-null    float64
#  17  rc        399 non-null    float64
#  18  htn       399 non-null    object
#  19  dm        399 non-null    object
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'Possible'],
#       dtype='object')

# %%
object_dtypes = dataset.select_dtypes(include = 'object')
object_dtypes.head()
# Out:
#   sg     rbc        pc         pcc          ba htn  dm cad appet    pe  ane
# 0  c  normal  abnormal  notpresent  notpresent  no  no  no   yes   yes   no
# 1  c  normal    normal  notpresent  notpresent  no  no  no   yes  poor   no
# 2  a  normal    normal  notpresent  notpresent  no  no  no   yes  poor   no
# 3  d  normal    normal  notpresent  notpresent  no  no  no   yes  poor  yes
# 4  c  normal    normal  notpresent  notpresent  no  no  no   yes  poor   no

# %%
dictonary = {
        "rbc": {
        "abnormal":1,
        "normal": 0,
    },
        "pc":{
        "abnormal":1,
        "normal": 0,
    },
        "pcc":{
        "present":1,
        "notpresent":0,
    },
        "ba":{
        "notpresent":0,
        "present": 1,
    },
        "htn":{
        "yes":1,
        "no": 0,
    },
        "dm":{
        "yes":1,
        "no":0,
    },
        "cad":{
        "yes":1,
        "no": 0,
    },
        "appet":{
        "yes":1,
        "poor": 0,
    },
        "pe":{
        "yes":1,
        "poor":0,
    },
        "ane":{
        "yes":1,
        "no":0,
    },
        "sg":{
        "a":0,
        "b":1,
        "c":2,
        "d":3,
        "e":4,
        }
}

# %%
dataset=dataset.replace(dictonary)

# %%
dataset
# Out:
#      age         bp  sg  al  su  rbc  pc  pcc  ba         bgr  ...        pcv  \
# 0      2  76.459948   2   3   0    0   1    0   0  148.112676  ...  38.868902
# 1      3  76.459948   2   2   0    0   0    0   0  148.112676  ...  34.000000
# 2      4  76.459948   0   1   0    0   0    0   0   99.000000  ...  34.000000
# 3      5  76.459948   3   1   0    0   0    0   0  148.112676  ...  38.868902
# 4      5  50.000000   2   0   0    0   0    0   0  148.112676  ...  36.000000
# ..   ...        ...  ..  ..  ..  ...  ..  ...  ..         ...  ...        ...
# 394   97  70.000000   0   0   0    0   0    0   0  219.000000  ...  37.000000
# 395   97  70.000000   2   0   2    0   0    0   0  220.000000  ...  27.000000
# 396   98  70.000000   2   3   0    0   0    0   0  110.000000  ...  26.000000
# 397   99  90.000000   0   0   0    0   0    0   0  207.000000  ...  38.868902
# 398   99  80.000000   0   0   0    0   0    0   0  100.000000  ...  53.000000
#
# ...

# %%
import seaborn as sns
plt.figure(figsize = (20,20))
sns.heatmap(dataset.corr(), annot = True, fmt=".2f",linewidths=0.5)
# Out:
# <Axes: >

# %%
dataset.corr()
# Out:
#                age        bp        sg        al        su       rbc  \
# age       1.000000  0.134790  0.091462  0.095510  0.166215  0.043705
# bp        0.134790  1.000000  0.180655  0.122499  0.190520  0.151650
# sg        0.091462  0.180655  1.000000  0.480166  0.302271  0.232814
# al        0.095510  0.122499  0.480166  1.000000  0.287877  0.394982
# su        0.166215  0.190520  0.302271  0.287877  1.000000  0.092625
# rbc       0.043705  0.151650  0.232814  0.394982  0.092625  1.000000
# pc        0.096214  0.157235  0.353727  0.561975  0.189691  0.377125
# pcc       0.129593  0.059806  0.273807  0.417998  0.167820  0.102667
# ba        0.027377  0.112354  0.204626  0.378011  0.119199  0.184225
# bgr       0.200505  0.149368  0.211323  0.310647  0.629678  0.152833
# bu        0.191248  0.184322  0.169204  0.347098  0.125677  0.236026
# sc        0.124566  0.144612  0.092048  0.160336  0.094271  0.138138
# sod      -0.083256 -0.103232 -0.129223 -0.228077 -0.053462 -0.140595
# ...

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'Possible'],
#       dtype='object')

# %%
indep=dataset[['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
       'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
       'appet', 'pe', 'ane',]]
dep=dataset['Possible']

# %%
indep
# Out:
#      age         bp  sg  al  su  rbc  pc  pcc  ba         bgr  ...       hrmo  \
# 0      2  76.459948   2   3   0    0   1    0   0  148.112676  ...  12.518156
# 1      3  76.459948   2   2   0    0   0    0   0  148.112676  ...  10.700000
# 2      4  76.459948   0   1   0    0   0    0   0   99.000000  ...  12.000000
# 3      5  76.459948   3   1   0    0   0    0   0  148.112676  ...   8.100000
# 4      5  50.000000   2   0   0    0   0    0   0  148.112676  ...  11.800000
# ..   ...        ...  ..  ..  ..  ...  ..  ...  ..         ...  ...        ...
# 394   97  70.000000   0   0   0    0   0    0   0  219.000000  ...  12.500000
# 395   97  70.000000   2   0   2    0   0    0   0  220.000000  ...   8.700000
# 396   98  70.000000   2   3   0    0   0    0   0  110.000000  ...   9.100000
# 397   99  90.000000   0   0   0    0   0    0   0  207.000000  ...   8.500000
# 398   99  80.000000   0   0   0    0   0    0   0  100.000000  ...  16.300000
#
# ...

# %%
dep
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 394    1
# 395    1
# 396    1
# 397    1
# 398    0
# Name: Possible, Length: 399, dtype: int64

# %%
#dataset=pd.get_dummies(dataset,drop_first=True).astype(int)

# %%
dataset["Possible"].value_counts()
# Out:
# Possible
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

param_grid = {'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':['auto','scale'],
             'C':[10,100,1000,2000,3000]} 



grid = GridSearchCV(SVC(probability=True), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter  
result=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

# %%
print(cm)
# Out:
# [[51  0]
#  [ 0 82]]

# %%
# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        51
#            1       1.00      1.00      1.00        82
#
#     accuracy                           1.00       133
#    macro avg       1.00      1.00      1.00       133
# weighted avg       1.00      1.00      1.00       133

# %%
#if you want chech f1 score use this
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}: 1.0

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 1.0

# %%
table=pd.DataFrame.from_dict(result)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.034378  3.030040e-02         0.015627        0.009885      10
# 1        0.009376  7.655201e-03         0.009376        0.007656      10
# 2        0.018750  6.249834e-03         0.009377        0.007656      10
# 3        0.009376  1.250110e-02         0.009375        0.007655      10
# 4        0.012501  1.169494e-02         0.012502        0.006251      10
# 5        0.009377  7.656252e-03         0.009377        0.007656      10
# 6        0.025002  7.650996e-03         0.006250        0.007655      10
# 7        0.006250  7.655006e-03         0.015638        0.009892      10
# 8        0.009370  7.650379e-03         0.009376        0.007655     100
# 9        0.009377  7.656058e-03         0.006251        0.007656     100
# 10       0.015629  3.328993e-06         0.006250        0.007654     100
# 11       0.006250  7.655181e-03         0.009375        0.007654     100
# ...

# %%
import pickle

# %%
filename = "CKD_Finalized_SVM_Model.sav"
pickle.dump(grid, open(filename, 'wb'))

# %%
model = pickle.load(open("CKD_Finalized_SVM_Model.sav",'rb'))

# %%
Future_Prediction=model.predict([[ 6, 60, 2, 4, 0, 0, 0, 0, 1, 94, 67, 1,135, 4.9, 9.9, 30, 16700, 4.8, 0,0,0,0,0 ,0]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]

# %%
age_input=float(input("age:"))
bp_input=float(input("bp:"))
sg_input=float(input("sg:"))
al_input=float(input("al:"))
su_input=float(input("su:"))
rbc_input=float(input("rbc:"))
pc_input=float(input("pc:"))
pcc_input=float(input("pcc:"))
ba_input=float(input("ba:"))
bgr_input=float(input("bgr:"))
bu_input=float(input("bu:"))
sc_input=float(input("sc:"))
sod_input=float(input("sod:"))
pot_input=float(input("pot:"))
hrmo_input=float(input("hrmo:"))
pcv_input=float(input("pcv:"))
wc_input=float(input("wc:"))
rc_input=float(input("rc:"))
htn_input=float(input("htn:"))
dm_input=float(input("dm:"))
cad_input=float(input("cad:"))
appet_input=float(input("appet:"))
pe_input=float(input("pe:"))
ane_input=float(input("ane:"))

# %%
Future_Prediction=model.predict([[age_input,bp_input, sg_input, al_input, su_input, rbc_input, pc_input, pcc_input, ba_input, bgr_input, bu_input, sc_input, sod_input, pot_input, hrmo_input, pcv_input, wc_input, rc_input, htn_input, dm_input, cad_input, appet_input, pe_input, ane_input]])
print("Future_Prediction={}".format(Future_Prediction))
