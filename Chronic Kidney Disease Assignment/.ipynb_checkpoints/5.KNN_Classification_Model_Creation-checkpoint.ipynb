# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('Chronic kidney disease prediction.csv')

# %%
dataset
# Out:
#      age         bp sg  al  su     rbc        pc         pcc          ba  \
# 0      2  76.459948  c   3   0  normal  abnormal  notpresent  notpresent
# 1      3  76.459948  c   2   0  normal    normal  notpresent  notpresent
# 2      4  76.459948  a   1   0  normal    normal  notpresent  notpresent
# 3      5  76.459948  d   1   0  normal    normal  notpresent  notpresent
# 4      5  50.000000  c   0   0  normal    normal  notpresent  notpresent
# ..   ...        ... ..  ..  ..     ...       ...         ...         ...
# 394   97  70.000000  a   0   0  normal    normal  notpresent  notpresent
# 395   97  70.000000  c   0   2  normal    normal  notpresent  notpresent
# 396   98  70.000000  c   3   0  normal    normal  notpresent  notpresent
# 397   99  90.000000  a   0   0  normal    normal  notpresent  notpresent
# 398   99  80.000000  a   0   0  normal    normal  notpresent  notpresent
#
#             bgr  ...        pcv            wc        rc  htn   dm  cad  appet  \
# 0    148.112676  ...  38.868902   8408.191126  4.705597   no   no   no    yes
# 1    148.112676  ...  34.000000  12300.000000  4.705597   no   no   no    yes
# 2     99.000000  ...  34.000000   8408.191126  4.705597   no   no   no    yes
# 3    148.112676  ...  38.868902   8408.191126  4.705597   no   no   no    yes
# 4    148.112676  ...  36.000000  12400.000000  4.705597   no   no   no    yes
# ..          ...  ...        ...           ...       ...  ...  ...  ...    ...
# 394  219.000000  ...  37.000000   9800.000000  4.400000   no   no   no    yes
# 395  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes   no    yes
# 396  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes   no   poor
# 397  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes   no    yes
# 398  100.000000  ...  53.000000   8500.000000  4.900000   no   no   no    yes
#
#        pe  ane Possible
# 0     yes   no      yes
# 1    poor   no      yes
# 2    poor   no      yes
# 3    poor  yes      yes
# 4    poor   no      yes
# ..    ...  ...      ...
# 394  poor   no      yes
# 395  poor  yes      yes
# 396  poor   no      yes
# 397  poor  yes      yes
# 398  poor   no       no
#
# [399 rows x 25 columns]

# %%
#it replaces 'yes' with 1 and 'no' with 0.
dataset['Possible'] = dataset['Possible'].replace(['yes','no'], [1,0])

# %%
dictonary = {
        "rbc": {
        "abnormal":1,
        "normal": 0,
    },
        "pc":{
        "abnormal":1,
        "normal": 0,
    },
        "pcc":{
        "present":1,
        "notpresent":0,
    },
        "ba":{
        "notpresent":0,
        "present": 1,
    },
        "htn":{
        "yes":1,
        "no": 0,
    },
        "dm":{
        "yes":1,
        "no":0,
    },
        "cad":{
        "yes":1,
        "no": 0,
    },
        "appet":{
        "yes":1,
        "poor": 0,
    },
        "pe":{
        "yes":1,
        "poor":0,
    },
        "ane":{
        "yes":1,
        "no":0,
    },
        "sg":{
        "a":0,
        "b":1,
        "c":2,
        "d":3,
        "e":4,
        }
}

# %%
dataset=dataset.replace(dictonary)

# %%
dataset
# Out:
#      age         bp  sg  al  su  rbc  pc  pcc  ba         bgr  ...        pcv  \
# 0      2  76.459948   2   3   0    0   1    0   0  148.112676  ...  38.868902
# 1      3  76.459948   2   2   0    0   0    0   0  148.112676  ...  34.000000
# 2      4  76.459948   0   1   0    0   0    0   0   99.000000  ...  34.000000
# 3      5  76.459948   3   1   0    0   0    0   0  148.112676  ...  38.868902
# 4      5  50.000000   2   0   0    0   0    0   0  148.112676  ...  36.000000
# ..   ...        ...  ..  ..  ..  ...  ..  ...  ..         ...  ...        ...
# 394   97  70.000000   0   0   0    0   0    0   0  219.000000  ...  37.000000
# 395   97  70.000000   2   0   2    0   0    0   0  220.000000  ...  27.000000
# 396   98  70.000000   2   3   0    0   0    0   0  110.000000  ...  26.000000
# 397   99  90.000000   0   0   0    0   0    0   0  207.000000  ...  38.868902
# 398   99  80.000000   0   0   0    0   0    0   0  100.000000  ...  53.000000
#
#                wc        rc  htn  dm  cad  appet  pe  ane  Possible
# 0     8408.191126  4.705597    0   0    0      1   1    0         1
# 1    12300.000000  4.705597    0   0    0      1   0    0         1
# 2     8408.191126  4.705597    0   0    0      1   0    0         1
# 3     8408.191126  4.705597    0   0    0      1   0    1         1
# 4    12400.000000  4.705597    0   0    0      1   0    0         1
# ..            ...       ...  ...  ..  ...    ...  ..  ...       ...
# 394   9800.000000  4.400000    0   0    0      1   0    0         1
# 395   8408.191126  4.705597    1   1    0      1   0    1         1
# 396   9200.000000  3.400000    1   1    0      0   0    0         1
# 397   8408.191126  4.705597    1   1    0      1   0    1         1
# 398   8500.000000  4.900000    0   0    0      1   0    0         0
#
# [399 rows x 25 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'Possible'],
#       dtype='object')

# %%
dataset["Possible"].value_counts()
# Out:
# Possible
# 1    249
# 0    150
# Name: count, dtype: int64

# %%
indep=dataset[['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
       'sc', 'sod', 'pot', 'hrmo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
       'appet', 'pe', 'ane',]]
dep=dataset['Possible']

# %%
indep.shape
# Out:
# (399, 24)

# %%
dep
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 394    1
# 395    1
# 396    1
# 397    1
# 398    0
# Name: Possible, Length: 399, dtype: int64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_= sc.fit_transform(X_train)
X_test_= sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Define the parameter grid
param_grid = {
    'n_neighbors': [5, 7, 9],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'metric': ['euclidean', 'manhattan', 'chebyshev']
}

# Create GridSearchCV
grid = GridSearchCV(KNeighborsClassifier(), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='f1')

# fitting the model for grid search
grid.fit(X_train_, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'metric': ['euclidean', 'manhattan', 'chebyshev'],
#                          'n_neighbors': [5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              scoring='f1', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test_) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        51
#            1       1.00      0.94      0.97        82
#
#     accuracy                           0.96       133
#    macro avg       0.96      0.97      0.96       133
# weighted avg       0.97      0.96      0.96       133

# %%
print(cm)
# Out:
# [[51  0]
#  [ 5 77]]

# %%
#if you want chech f1 score use this
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'algorithm': 'auto', 'metric': 'chebyshev', 'n_neighbors': 5, 'weights': 'distance'}: 0.9626932787797391

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# C:\Users\ELCOT\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# 0.5

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006251      0.007655         0.071880        0.018751
# 1        0.000000      0.000000         0.043754        0.006251
# 2        0.006251      0.007656         0.078130        0.013968
# 3        0.003126      0.006252         0.062505        0.000002
# 4        0.000000      0.000000         0.071882        0.015935
# ..            ...           ...              ...             ...
# 67       0.000000      0.000000         0.040627        0.007659
# 68       0.003126      0.006252         0.040627        0.007658
# 69       0.000000      0.000000         0.050005        0.006251
# 70       0.003125      0.006250         0.040623        0.007658
# 71       0.000000      0.000000         0.043752        0.006251
#
#    param_algorithm param_metric param_n_neighbors param_weights  \
# 0             auto    euclidean                 5       uniform
# 1             auto    euclidean                 5      distance
# 2             auto    euclidean                 7       uniform
# 3             auto    euclidean                 7      distance
# 4             auto    euclidean                 9       uniform
# ..             ...          ...               ...           ...
# 67           brute    chebyshev                 5      distance
# 68           brute    chebyshev                 7       uniform
# 69           brute    chebyshev                 7      distance
# 70           brute    chebyshev                 9       uniform
# 71           brute    chebyshev                 9      distance
#
#                                                params  split0_test_score  \
# 0   {'algorithm': 'auto', 'metric': 'euclidean', '...           0.866667
# 1   {'algorithm': 'auto', 'metric': 'euclidean', '...           0.885246
# 2   {'algorithm': 'auto', 'metric': 'euclidean', '...           0.866667
# 3   {'algorithm': 'auto', 'metric': 'euclidean', '...           0.866667
# 4   {'algorithm': 'auto', 'metric': 'euclidean', '...           0.866667
# ..                                                ...                ...
# 67  {'algorithm': 'brute', 'metric': 'chebyshev', ...           0.903226
# 68  {'algorithm': 'brute', 'metric': 'chebyshev', ...           0.866667
# 69  {'algorithm': 'brute', 'metric': 'chebyshev', ...           0.866667
# 70  {'algorithm': 'brute', 'metric': 'chebyshev', ...           0.866667
# 71  {'algorithm': 'brute', 'metric': 'chebyshev', ...           0.866667
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.969697           0.918033           0.984615
# 1            0.969697           0.918033           0.984615
# 2            0.969697           0.900000           0.984615
# 3            0.969697           0.918033           0.984615
# 4            0.969697           0.900000           0.984615
# ..                ...                ...                ...
# 67           0.985507           0.935484           0.984615
# 68           0.955224           0.935484           0.984615
# 69           0.955224           0.935484           0.984615
# 70           0.955224           0.935484           0.968750
# 71           0.955224           0.935484           0.968750
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.984615         0.944725        0.046069               40
# 1            0.984615         0.948441        0.039968               31
# 2            0.984615         0.941119        0.048651               57
# 3            0.984615         0.944725        0.046069               40
# 4            0.984615         0.941119        0.048651               57
# ..                ...              ...             ...              ...
# 67           0.984615         0.958690        0.033699                1
# 68           0.984615         0.945321        0.043519               36
# 69           0.984615         0.945321        0.043519               36
# 70           0.984615         0.942148        0.041046               53
# 71           0.984615         0.942148        0.041046               53
#
# [72 rows x 17 columns]

# %%
Future_Prediction=grid.predict([[ 6, 60, 2, 4, 0, 0, 0, 0, 1, 94, 67, 1,135, 4.9, 9.9, 30, 16700, 4.8, 0,0,0,0,0 ,0]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
